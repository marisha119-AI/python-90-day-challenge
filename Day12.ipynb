# %% [markdown]
# # 📘 Day 12: Tuples & Sets

# %% [markdown]
# ✅ Q1. What is a tuple in Python?

# %% [markdown]
# ## A tuple is an ordered collection of elements that cannot be changed (immutable).

# %%
t = (1, 2, 3)
print(t)
# Out:
# (1, 2, 3)

# %% [markdown]
# ✅ Q2. Create a tuple of 5 fruits

# %%
fruits = ("apple", "banana", "mango", "orange", "grapes")
print(fruits)
# Out:
# ('apple', 'banana', 'mango', 'orange', 'grapes')

# %% [markdown]
# ✅ Q3. Access the first and last element of a tuple

# %%
numbers = (10, 20, 30, 40, 50)
print(numbers[0])
print(numbers[-1])
# Out:
# 10
# 50

# %% [markdown]
# ✅ Q4. Check if an element exists in a tuple

# %%
t = (1, 2, 3, 4)

if 3 in t:
    print("Element found")
else:
    print("Element not found")
# Out:
# Element found

# %% [markdown]
# ✅ Q5. Convert a tuple into a list

# %%
t = (5, 10, 15)
lst = list(t)
print(lst)
# Out:
# [5, 10, 15]

# %% [markdown]
# ✅ Q6. Convert a list into a tuple

# %%
lst = [1, 2, 3]
t = tuple(lst)
print(t)
# Out:
# (1, 2, 3)

# %% [markdown]
# ✅ Q7. What is a set in Python?

# %% [markdown]
# ## A set is an unordered collection of unique elements.

# %%
s = {1, 2, 3}
print(s)
# Out:
# {1, 2, 3}

# %% [markdown]
# ✅ Q8. Create a set and add a new element

# %%
s = {1, 2, 3}
s.add(4)
print(s)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# ✅ Q9. Remove duplicate elements from a list using a set

# %%
numbers = [1, 2, 2, 3, 4, 4, 5]
unique_numbers = list(set(numbers))
print(unique_numbers)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ✅ Q10. Find the union of two sets

# %%
set1 = {1, 2, 3}
set2 = {3, 4, 5}

result = set1 | set2
print(result)
# Out:
# {1, 2, 3, 4, 5}
