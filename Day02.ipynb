# %% [markdown]
# .
#
#                                         🟢 Day 2: 10 MORE PYTHON QUESTIONS (BEGINNER)

# %% [markdown]
# Q11.
#
# Write a Python program that stores two numbers in variables and prints:
#
# The sum of <num1> and <num2> is <result>

# %%
num1= 56
num2= 69
result= num1 + num2
print(" The sum of" , num1, "and" , num2 , "is", result)
# Out:
#  The sum of 56 and 69 is 125

# %% [markdown]
# Q12.
#
# Write a Python program that stores your first name and last name in two variables and prints them in one line.

# %%
first_name= "Neha"
last_name= " Tiwari"
print(first_name + last_name)
# Out:
# Neha Tiwari

# %% [markdown]
# Q13.
#
# Write a Python program that stores a number and prints whether its data type is int or float.

# %%
num= 589
if type(num) == int:
    print( "Number is Integer")
else:
    print("Number is Float")
# Out:
# Number is Integer

# %% [markdown]
# Q14.
#
# Write a Python program to store a number as a string and then print its type.

# %%
num= ("6787")
print(type(num))
# Out:
# <class 'str'>

# %% [markdown]
# Q15.
#
# Write a Python program that prints the square of a number.

# %%
num= 5
square= num **2
print("square of a number is :", square)
# Out:
# square of a number is : 25

# %% [markdown]
# Q16.
#
# Write a Python program that prints the cube of a number.

# %%
num = 78
cube= num** 3
print("cube of a number is :", cube)
# Out:
# cube of a number is : 474552

# %% [markdown]
# Q17.
#
# Write a Python program that stores three numbers and prints their average.

# %%
num= (56, 98, 69)
average= sum(num)/ 3
print("Average of a numbers is :", average)
# Out:
# Average of a numbers is : 74.33333333333333

# %% [markdown]
# Q18.
#
# Write a Python program to store a value and print whether it is a string or a number.

# %%
value= 87
if type(value)== int:
    print("value is integer")
else:
    print("value is string")
# Out:
# value is integer

# %% [markdown]
# Q19.
#
# Write a Python program that uses both text and numbers in a single print() statement.

# %%
age= 25
print("My age is ", age)
# Out:
# My age is  25

# %% [markdown]
# Q20.
#
# Predict the output of the following code, then run it to verify:
#
# a = "5"
# b = 5
# print(a + str(b))

# %%
a = "5"  #this is String  containing 5
b = 5     #this is Intiger 
print(a + str(b))
# Out:
# 55
