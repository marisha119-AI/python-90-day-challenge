# %% [markdown]
#  # 🔵 DAY 3 –  PYTHON QUESTIONS (INPUT & TYPE CASTING)

# %% [markdown]
# #q21.
#
# Take two numbers as input and print the greater number.

# %%
num1 = int(input("Enter a 1st number"))
num2 = int(input("Enter a 2nd number")) 
if num1> num2:
           print(num1 , "Is greater than ", num2)
else:
            print(num2 , "Is greater than ", num1)
# Out:
# Enter a 1st number 87
# Enter a 2nd number 92
# 92 Is greater than  87

# %% [markdown]
# # Q22.
#
# Take a number as input and check whether it is positive, negative, or zero.

# %%
num = int(input("Enter a number"))
if num>= 1:
    print("Number is positive")
elif num == 0:
    print("Number is Zero")
else:
    print("Number is negative")
# Out:
# Enter a number 0
# Number is Zero

# %% [markdown]
# Q23.
#
# Take a number as input and check whether it is divisible by 3 and 5.

# %%
num = int(input("Enter a number"))
if num % 3== 0 and num % 5 == 0:
    print("True")

else:
    print("False")
# Out:
# Enter a number 8
# False

# %% [markdown]
# Q 24. Take three numbers as input and print their average.

# %%
num1 = int(input("Enter a 1st number"))
num2 = int(input("Enter a 2nd number")) 
num3 = int(input("Enter a 3rd number"))
average= num1+ num2+ num3/ 3
print(average)
# Out:
# Enter a 1st number 67
# Enter a 2nd number 38
# Enter a 3rd number 82
# 132.33333333333334

# %% [markdown]
# Q 25. Take length and breadth as input and calculate:
# area of rectangle
# perimeter of rectangle

# %%
length = float(input("Enter a length :"))
breadth= float(input("Enter a breadth"))
area = length * breadth
perimeter = 2 * (length + breadth)

print("Area of the rectangle is:", area)
print("Perimeter of the rectangle is:", perimeter)
# Out:
# Enter a length : 94
# Enter a breadth 89
# Area of the rectangle is: 8366.0
# Perimeter of the rectangle is: 366.0

# %% [markdown]
# Q26.
#
# Take marks of 5 subjects as input and calculate:
#
# total marks
#
# average marks

# %%
sub1 = float(input("Enter marks of subject 1: "))
sub2 = float(input("Enter marks of subject 2: "))
sub3 = float(input("Enter marks of subject 3: "))
sub4 = float(input("Enter marks of subject 4: "))
sub5 = float(input("Enter marks of subject 5: "))

total = sub1 + sub2 + sub3 + sub4 + sub5
average = total / 5

print("Total marks:", total)
print("Average marks:", average)
# Out:
# Enter marks of subject 1:  68
# Enter marks of subject 2:  56
# Enter marks of subject 3:  49
# Enter marks of subject 4:  72
# Enter marks of subject 5:  75
# Total marks: 320.0
# Average marks: 64.0

# %% [markdown]
# Q 27. Take a person’s name and year of birth as input and print their current age.

# %%
name = input("Enter your name: ")
birth_year = int(input("Enter your year of birth: "))

current_year = 2026
age = current_year - birth_year

print("Hello", name)
print("Your current age is:", age)
# Out:
# Enter your name:  Neha
# Enter your year of birth:  1995
# Hello Neha
# Your current age is: 31

# %% [markdown]
# Q28. Take a total bill amount as input and:
# add 5% tax
# print the final amount to pay

# %%
bill_amount = float(input("Enter the total bill amount: "))

tax = bill_amount * 5 / 100
final_amount = bill_amount + tax

print("Tax amount (5%):", tax)
print("Final amount to pay:", final_amount)
# Out:
# Enter the total bill amount:  2021
# Tax amount (5%): 101.05
# Final amount to pay: 2122.05

# %% [markdown]
# Q 29. Take a string as input and print:
# the length of the string
# the string in uppercase

# %%
value= input("Enter a string")
lenght= len(value)
uppercase= value.upper()
print("the length of the string:",lenght )
print("the string in uppercase", uppercase )
# Out:
# Enter a string Marisha Dwivedi
# the length of the string: 15
# the string in uppercase MARISHA DWIVEDI

# %% [markdown]
# q 30. Take distance (km) and time (hours) as input and calculate speed.

# %%
distance = float(input("Enter distance in kilometers: "))
time = float(input("Enter time in hours: "))

speed = distance / time

print("Speed is:", speed, "km/hour")
# Out:
# Enter distance in kilometers:  234
# Enter time in hours:  3
# Speed is: 78.0 km/hour
