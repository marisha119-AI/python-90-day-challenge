# %% [markdown]
# # 📘 Day 16: Modules & Packages

# %% [markdown]
# ✅ Q1. What is a module in Python?

# %% [markdown]
# A module is a Python file that contains functions, variables, or classes which can be reused in other programs.

# %% [markdown]
# import math
# print(math.sqrt(16))

# %% [markdown]
# ✅ Q2. Why do we use modules?

# %% [markdown]
# We use modules to:
#
# Reuse code
#
# Keep programs organized
#
# Avoid writing the same code again

# %% [markdown]
# ✅ Q3. Import a built-in module and use it

# %% [markdown]
# import math
# print(math.factorial(5))

# %% [markdown]
# ✅ Q4. Import only a specific function from a module

# %% [markdown]
# from math import sqrt
# print(sqrt(25))

# %% [markdown]
# ✅ Q5. Use as keyword to rename a module

# %% [markdown]
# import math as m
# print(m.pi)

# %% [markdown]
# ✅ Q6. What is a package in Python?

# %% [markdown]
# A package is a collection of multiple modules stored inside a folder.

# %% [markdown]
# ✅ Q7. Create and use your own module (example)

# %% [markdown]
# def greet(name):
#     print("Hello", name)

# %% [markdown]
# ✅ Q8. List some common built-in modules

# %% [markdown]
# Some common built-in modules are:
#
# math
#
# random
#
# datetime
#
# os
#
# sys

# %% [markdown]
# ✅ Q9. Generate a random number using random module

# %% [markdown]
# import random
# print(random.randint(1, 10))

# %% [markdown]
# ✅ Q10. Get today’s date using datetime module

# %% [markdown]
# import datetime
# today = datetime.date.today()
# print(today)
