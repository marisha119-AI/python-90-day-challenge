# %% [markdown]
# # 📘 Day 13: Dictionaries

# %% [markdown]
# ✅ Q1. What is a dictionary in Python?

# %% [markdown]
# A dictionary stores data in key–value pairs.

# %%
student = {"name": "Marisha", "age": 21}
print(student)
# Out:
# {'name': 'Marisha', 'age': 21}

# %% [markdown]
# ✅ Q2. Create a dictionary with name, age, and city

# %%
person = {
    "name": "Marisha",
    "age": 21,
    "city": "Delhi"
}
print(person)
# Out:
# {'name': 'Marisha', 'age': 21, 'city': 'Delhi'}

# %% [markdown]
# ✅ Q4. Add a new key–value pair to a dictionary

# %%
person["profession"] = "Student"
print(person)
# Out:
# {'name': 'Marisha', 'age': 21, 'city': 'Delhi', 'profession': 'Student'}

# %% [markdown]
# ✅ Q5. Update the value of an existing key

# %%
person["age"] = 22
print(person)
# Out:
# {'name': 'Marisha', 'age': 22, 'city': 'Delhi', 'profession': 'Student'}

# %% [markdown]
# ✅ Q6. Remove a key from a dictionary

# %%
person.pop("city")
print(person)
# Out:
# {'name': 'Marisha', 'age': 22, 'profession': 'Student'}

# %% [markdown]
# ✅ Q7. Loop through a dictionary and print keys

# %%
for key in person:
    print(key)
# Out:
# name
# age
# profession

# %% [markdown]
# ✅ Q8. Loop through a dictionary and print values

# %%
for value in person.values():
    print(value)
# Out:
# Marisha
# 22
# Student

# %% [markdown]
# ✅ Q9. Loop through keys and values together

# %%
for key, value in person.items():
    print(key, ":", value)
# Out:
# name : Marisha
# age : 22
# profession : Student

# %% [markdown]
# ✅ Q10. Check if a key exists in a dictionary

# %%
if "name" in person:
    print("Key exists")
else:
    print("Key does not exist")
# Out:
# Key exists
