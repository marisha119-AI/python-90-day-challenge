# %% [markdown]
# # 🐍 💡 Day 11 – Different Type Questions

# %% [markdown]
# 1️⃣ Swap two numbers (without third variable)
# ❓ Question:
#
# Swap two numbers without using extra variable.

# %%
a= 6
b= 9
a, b= b, a
print(a)
print(b)
# Out:
# 9
# 6

# %% [markdown]
# 2️⃣ Count how many times a character appears
# ❓ Question:
#
# Count how many times letter 'a' appears in a string.

# %%
text = "banana"
count = 0
for char in text:
    if char == "a":
        count += 1

print(count)
# Out:
# 3

# %% [markdown]
# ❓ Question:
#
# Remove all spaces from a sentence.

# %%
text= "I Love India"
text_new= text.replace(" ", "")
print(text_new)
# Out:
# ILoveIndia

# %% [markdown]
#  4️⃣ Find second largest number
#
# ❓ Question:
#
# Find second largest number in list.

# %%
a= [1,2,3,4,5,16,7]
a.sort()
print(a[-2])
# Out:
# 7

# %% [markdown]
# 5️⃣ Check if string is palindrome
#
# ❓ Question:
#
# Check whether a string is palindrome.

# %%
text = input("Enter word: ")

if text == text[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter word:  "Delhi is Capital of India"
# Not Palindrome

# %% [markdown]
# 6️⃣ Find factorial of a number
#
# ❓ Question:
#
# Find factorial using loop.

# %%
num = int(input("Enter number: "))
fact = 1

for i in range(1, num + 1):
    fact *= i

print("Factorial:", fact)
# Out:
# Enter number:  5
# Factorial: 120

# %% [markdown]
# 7️⃣ Find common elements in two lists
#
# ❓ Question:
#
# Find common numbers from two lists.

# %%
a= [2,5,7,8,9,10]
b= [8,5, 10, 1, 3]
for num in a:
    if num in b:
        print(num)
# Out:
# 5
# 8
# 10

# %% [markdown]
#  8️⃣ Convert Celsius to Fahrenheit
# ❓ Question:
#
# Convert temperature.

# %%
Celsius= float(input("Enter a temrature:"))
Fahrenheit= Celsius * 9/5 + 32
print(Fahrenheit)
# Out:
# Enter a temrature: 52
# 125.6

# %% [markdown]
# 9️⃣ Count words in sentence
#
# ❓ Question:
#
# Count total words in sentence.

# %%
text = input("Enter sentence: ")
words = text.split()

print("Total words:", len(words))
# Out:
# Enter sentence:  "I am Marisha"
# Total words: 3

# %% [markdown]
# 🔟 Print only positive numbers from list
#
# ❓ Question:
#
# Print positive numbers.

# %%
numbers = [-5, 10, -3, 8, 0]

for num in numbers:
    if num > 0:
        print(num)
# Out:
# 10
# 8
