# %% [markdown]
#                                          📘 Day 1: Python Basics - 10 Beginner Problems
#
#
# Q1.Write a Python program to print:
#
#  Hello Python

# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# Q2.Write a Python program to print your:
#
# Name
#
# Course
#
# City
#
# (Use three print() statements.)

# %%
Name= "Marisha"
Course= "AI Developer"
City = "Delhi"
print(Name)
print(Course)
print(City)
# Out:
# Marisha
# AI Developer
# Delhi

# %% [markdown]
# Q3.Write a Python program that prints any two sentences on two different lines.

# %%
print("I am Marisha. \nI am learning AI skills.")
# Out:
# I am Marisha.
# I am learning AI skills

# %% [markdown]
# Q4.What is a comment in Python?
# Write one example of a single-line comment and print a message below it.

# %%
A comment in Python is a line that is not executed by the program.
It is used to explain the code so that it is easy to understand.

# %%
# This is a single-line comment
print("This line will be executed")
# Out:
# This line will be executed

# %% [markdown]
# Q5.
#
# Write a Python program to print the result of addition of two numbers.

# %%
num1= int(input("Enter 1st number"))
num2= int(input("Enter 2nd number"))
print(num1+ num2)
# Out:
# Enter 1st number 73
# Enter 2nd number 69
# 142

# %% [markdown]
# Q6. Write a Python program to print your favorite color.

# %%
color= ("Blue")
print(f"My favorite color is {color}.")
# Out:
# My favorite color is Blue.

# %% [markdown]
# Q7. Write a Python program to print the type of a number using type().

# %%
num= 68.93
print(type(num))
# Out:
# <class 'float'>

# %% [markdown]
# Q8.
#
# Write a Python program to print a message using single quotes.

# %%
a= ('Python is high level programming language')
print(a)
# Out:
# Python is high level programming language

# %% [markdown]
# Q19.
#
# What will be the output of the following code?
# print(10)
# print("10")

# %%
print(10)      #this is integer
print("10")    #this is string
# Out:
# 10
# 10

# %% [markdown]
# Q10.
# Fill in the blank to make the program print the message correctly:
# fruit = "mango"
#
# # Fill in the blank below
# print(_______________)

# %%
fruit = "mango"
print(fruit)
# Out:
# mango
